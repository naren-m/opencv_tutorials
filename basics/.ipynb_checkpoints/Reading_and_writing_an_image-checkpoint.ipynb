# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load the image and show some basic information on it
image = cv2.imread('hongkong_airport.jpg')
print "width: %d pixels" % (image.shape[1])
print "height: %d pixels" % (image.shape[0])
print "channels: %d" % (image.shape[2])
# Out:
# ---------------
# AttributeErrorTraceback (most recent call last)
# <ipython-input-10-d2e029af0e2d> in <module>()
#       1 # load the image and show some basic information on it
#       2 image = cv2.imread('hongkong_airport.png')
# ----> 3 print "width: %d pixels" % (image.shape[1])
#       4 print "height: %d pixels" % (image.shape[0])
#       5 print "channels: %d" % (image.shape[2])
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
cv_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

plt.axis("off")
plt.imshow(cv_rgb)

# cv2.imwrite("newimage.jpg", image)

# %time
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 9.06 µs

# %%
print "OpenCV Version : %s " % cv2.__version__
# Out:
# OpenCV Version : 3.1.0

# %%
import sys

sys.path.append('/code/opencv_tutorials')
from image_utils import Ipy

# %%
Ipy.showimage(image)
# %time
# Out:
# CPU times: user 0 ns, sys: 0 ns, total: 0 ns
# Wall time: 10 µs
